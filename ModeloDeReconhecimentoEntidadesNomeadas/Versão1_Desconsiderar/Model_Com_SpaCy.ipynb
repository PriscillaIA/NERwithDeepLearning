# %% [markdown]
# # Importações

# %%
import re
import spacy
import pickle
import os
import pandas as pd
import csv
import glob
import csv
from spacy.training import offsets_to_biluo_tags
from spacy.training import biluo_tags_to_spans
from spacy.training import offsets_to_biluo_tags, biluo_tags_to_offsets, biluo_tags_to_spans
import itertools

# importações para o bloco de código do treinamento do modelo de NER
import random
from spacy.util import minibatch, compounding
from pathlib import Path
from spacy.tokens import Doc
from spacy.training import Example
import warnings
import datetime as date

# %% [markdown]
# ### Carregando Dados Rotulados Manualmente Para Treinamento do Modelo

# %% [markdown]
# Carrega os dados no formato .csv e cria um dataframe a partir deles.

# %%
dataSet = pd.read_csv("../DataSets/Dataset_Padrao_IOB_Versao4.csv", usecols=['Palavras', 'Rotulo', 'Sentenca', 'Inicio', 'Fim'])

# %% [markdown]
# Carrega a base utilizada para rotulação manual das categorias. Utilizada para extrair as setenças a que cada token rotulado pertence.

# %%
with open("/home/arthur/Documentos/IC/git/ProjetoMestrado/DataSets/Dados_Utilizados_Para_RotulacaoManual.txt", "r", encoding='utf-8') as file:
    textos = file.read().splitlines()
print("Quantidade de linhas da base:" , len(textos))
# Out:
# Quantidade de linhas da base: 14628

# %% [markdown]
# Código para converter os dados que estão no formato IOB para o formato do spaCy

# %%
sMarker = 0 #Marcador que referência a qual setença a entidade pertence, ou seja, serve pra pegar o texto da referencia dos tokens no dataset
s = textos[sMarker]
dataSetEntrada = []
entities = []
for index, row in dataSet.iterrows():
    
    if(row['Sentenca']-1 != sMarker): # Nova sentença
        if entities:
            dataSetEntrada.append((s, {"entities": [tuple(e) for e in entities]})) # Salva sentença anterior
        entities = [] # esvazia entidades
        sMarker = row['Sentenca']-1 # atualiza o marcador de sentença
        
        if (sMarker < len(textos)): # Limite de textos
            s = textos[sMarker]

    if(row['Rotulo'][0] == 'B'):
         entities.append([row['Inicio'], row['Fim'], row['Rotulo'][2:]])
    if(row['Rotulo'][0] == 'I'):
        if (entities): 
            entities[-1][1] = row['Fim']
        else:
            # print(index)
            entities.append([row['Inicio'], row['Fim'], row['Rotulo'][2:]])
    
    if index == dataSet.index[-1]: # Ultimo elemento
        if entities:
            dataSetEntrada.append((s, {"entities": [tuple(e) for e in entities]}))
        entities = [] 


print('Quantidade Sentenças Rotuladas:', len(dataSetEntrada))
# Out:
# Quantidade Sentenças Rotuladas: 11294

# %%
TRAIN_DATA = dataSetEntrada[0:899]
TEST_DATA = dataSetEntrada[900:999]
#for index, item in enumerate(TRAIN_DATA):
    #print(index)

# %%
TEST_DATA
# Out:
# [('A Cachaça Dom Bré Amburana é elaborada com requinte e arte, respeitando as tradições seculares de produção da Cachaça Mineira.',
#   {'entities': [(10, 17, 'NOME_BEBIDA'), (18, 26, 'TIPO_MADEIRA')]}),
#  ('Após a destilação, a Cachaça Dom Bré é armazenada em tonéis de Amburana, o que lhe confere aroma agradável e um sabor suave, especial e inigualável.',
#   {'entities': [(29, 36, 'NOME_BEBIDA'),
#     (53, 59, 'RECIPIENTE_ARMAZENAMENTO'),
#     (63, 71, 'TIPO_MADEIRA')]}),
#  ('Armazenada em tonéis de amburana por um longo tempo, selecionada e elaborada harmoniozamente, com notas amadeiradas, frutadas e florais, com sabor e aroma exclusivos de uma bebida singular.',
#   {'entities': [(14, 20, 'RECIPIENTE_ARMAZENAMENTO'),
#     (24, 32, 'TIPO_MADEIRA'),
#     (98, 115, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (117, 125, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (128, 135, 'CARACTERISTICA_SENSORIAL_SABOR')]}),
#  ('Origem: Guarani / MG Madeira: Amburana Envelhecimento: 3 anos Grad.',
#   {'entities': [(8, 15, 'NOME_LOCAL'),
#     (18, 20, 'NOME_LOCAL'),
#     (30, 38, 'TIPO_MADEIRA'),
#     (55, 61, 'TEMPO_ARMAZENAMENTO')]}),
#  ('Alcoólica: 40% Volume: 700ml',
#   {'entities': [(11, 14, 'GRADUACAO_ALCOOLICA'), (23, 28, 'VOLUME')]}),
#  ('Volume: 700ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('GRADUAÇÃO ALCOÓLICA: 40%', {'entities': [(21, 24, 'GRADUACAO_ALCOOLICA')]}),
#  ('RECIPIENTE DE ARMAZENAMENTO: Amburana',
#   {'entities': [(29, 37, 'TIPO_MADEIRA')]}),
#  ('LOCAL DE PRODUÇÃO: Guarani / MG',
#   {'entities': [(19, 26, 'NOME_LOCAL'), (29, 31, 'NOME_LOCAL')]}),
#  ('TEMPO DE ARMAZENAMENTO: 3 anos',
#   {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}),
#  ('NOME DA CACHAÇA: Cachaça SANTO GRAU CORONEL XAVIER CHAVES Garrafa 750ml',
#   {'entities': [(25, 57, 'NOME_BEBIDA'), (66, 71, 'VOLUME')]}),
#  ('PREÇO: R$ 59,99', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: A Cachaça Santo Grau Coronel Xavier Chaves 750ml é produzida no alambique mais antigo em atividade no Brasil, localizado em Coronel Xavier Chaves, na Estrada Real, próximo a Tiradentes e São João Del Rey.',
#   {'entities': [(32, 64, 'NOME_BEBIDA'),
#     (65, 70, 'VOLUME'),
#     (124, 130, 'NOME_LOCAL'),
#     (146, 167, 'NOME_LOCAL'),
#     (172, 184, 'NOME_LOCAL'),
#     (196, 206, 'NOME_LOCAL'),
#     (209, 225, 'NOME_LOCAL')]}),
#  ('Armazenada em tonéis de inox por seis meses, possui graduação alcoólica de 40%.',
#   {'entities': [(14, 28, 'RECIPIENTE_ARMAZENAMENTO'),
#     (33, 43, 'TEMPO_ARMAZENAMENTO'),
#     (75, 78, 'GRADUACAO_ALCOOLICA')]}),
#  ('Volume: 750ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Insinuante 670ml',
#   {'entities': [(25, 35, 'NOME_BEBIDA'), (36, 41, 'VOLUME')]}),
#  ('PREÇO: R$ 35,90', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: Descrição A Insinuante umburana apresenta um cheiro acentuado, cor amarelada e bouquet característico.',
#   {'entities': [(34, 44, 'NOME_BEBIDA'),
#     (45, 53, 'TIPO_MADEIRA'),
#     (74, 83, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (89, 98, 'CARACTERISTICA_SENSORIAL_COR'),
#     (101, 108, 'CARACTERISTICA_SENSORIAL_COR')]}),
#  ('É uma cachaça encorpada com acidez bastante equilibrada.',
#   {'entities': [(14, 23, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'),
#     (28, 55, 'CARACTERISTICA_SENSORIAL_SABOR')]}),
#  ('– Armazenada por 01 ano em tonéis de umburana.',
#   {'entities': [(17, 23, 'TEMPO_ARMAZENAMENTO'),
#     (27, 33, 'RECIPIENTE_ARMAZENAMENTO'),
#     (37, 45, 'TIPO_MADEIRA')]}),
#  ('– Graduação alcoólica 48% vol.',
#   {'entities': [(22, 25, 'GRADUACAO_ALCOOLICA')]}),
#  ('– Indicada para ser apreciada pura – Origem: Januária (MG)',
#   {'entities': [(45, 53, 'NOME_LOCAL'), (55, 57, 'NOME_LOCAL')]}),
#  ('Volume: 670ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Engenho Fazenda Velha Ouro 700ml',
#   {'entities': [(25, 46, 'NOME_BEBIDA'),
#     (47, 51, 'CLASSIFICACAO_BEBIDA'),
#     (52, 57, 'VOLUME')]}),
#  ('PREÇO: R$ 69,90', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: A Cachaça Ouro da Fazenda Velha já foi a ganhadora do título de melhor cachaça envelhecida no ano de 2012, através do VIII concurso de qualidade de cachaça, oferecido pela Universidade Estadual de São Paulo.',
#   {'entities': [(32, 36, 'CLASSIFICACAO_BEBIDA'),
#     (40, 53, 'NOME_ORGANIZACAO'),
#     (123, 127, 'TEMPO'),
#     (194, 228, 'NOME_ORGANIZACAO')]}),
#  ('Volume: 700ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Cavaco Prata 700ml',
#   {'entities': [(25, 31, 'NOME_BEBIDA'),
#     (32, 37, 'CLASSIFICACAO_BEBIDA'),
#     (38, 43, 'VOLUME')]}),
#  ('PREÇO: R$ 45,90', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: A Cachaça Cavaco é a primeira produzida integralmente no Distrito Federal, fruto do sonho de tornar a capital do país expoente na bebida nacional, remetendo, assim, ao próprio surgimento de Brasília, um projeto pioneiro e inovador.',
#   {'entities': [(32, 38, 'NOME_BEBIDA'),
#     (79, 95, 'NOME_LOCAL'),
#     (212, 220, 'NOME_LOCAL')]}),
#  ('O Canavial da Fazenda Cavaco, cravado no Planalto Central e oriundo de canas-de-açúcar selecionadsa, serve como base para a produção do fermento com leveduras selvagens, proporcionando sabor e aroma únicos que remetem o coração do Brasil.',
#   {'entities': [(14, 28, 'NOME_ORGANIZACAO'),
#     (199, 205, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (231, 237, 'NOME_LOCAL')]}),
#  ('Volume: 700ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Estância Moretti Imburana 750ml',
#   {'entities': [(25, 41, 'NOME_BEBIDA'),
#     (42, 50, 'TIPO_MADEIRA'),
#     (51, 56, 'VOLUME')]}),
#  ('PREÇO: R$ 399,99', {'entities': [(7, 16, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: Visual: - Cristalino, Oleosidade e com lágrimas caindo no tempo correto.',
#   {'entities': [(32, 42, 'CARACTERISTICA_SENSORIAL_COR'),
#     (44, 54, 'CARACTERISTICA_SENSORIAL_COR')]}),
#  ('Aroma: - Aroma bem adocicado herbal com notas marcantes de especiarias como canela e baunilha.',
#   {'entities': [(19, 35, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (59, 70, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (76, 82, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (85, 93, 'CARACTERISTICA_SENSORIAL_AROMA')]}),
#  ('Boca: Macia aveludada com uma leve e interessante apimentadinha e baixíssima acidez.',
#   {'entities': [(6, 11, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'),
#     (12, 21, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'),
#     (50, 63, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (66, 83, 'CARACTERISTICA_SENSORIAL_SABOR')]}),
#  ('Retrogosto: bem amadeirado persistente e alongado.',
#   {'entities': [(12, 26, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (27, 38, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (41, 49, 'CARACTERISTICA_SENSORIAL_SABOR')]}),
#  ('Origem: Jandaia do Sul - PR Madeira:Amburana (Imburana).',
#   {'entities': [(8, 22, 'NOME_LOCAL'),
#     (25, 27, 'NOME_LOCAL'),
#     (36, 44, 'TIPO_MADEIRA'),
#     (46, 54, 'TIPO_MADEIRA')]}),
#  ('Envelhecimento: Descansada em barril de Amburana (Imburana).',
#   {'entities': [(30, 36, 'RECIPIENTE_ARMAZENAMENTO'),
#     (40, 48, 'TIPO_MADEIRA'),
#     (50, 58, 'TIPO_MADEIRA')]}),
#  ('Graduação Alcoólica: 40% Volume: Garrafa de vidro padronizada de 500ml',
#   {'entities': [(21, 24, 'GRADUACAO_ALCOOLICA'), (65, 70, 'VOLUME')]}),
#  ('Volume: 750ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Estância Moretti 4 Madeiras 500ml',
#   {'entities': [(25, 41, 'NOME_BEBIDA'), (53, 58, 'VOLUME')]}),
#  ('PREÇO: R$ 399,99', {'entities': [(7, 16, 'PRECO')]}),
#  ('Volume: 500ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Remedin Ouro 500ml',
#   {'entities': [(25, 32, 'NOME_BEBIDA'),
#     (33, 37, 'CLASSIFICACAO_BEBIDA'),
#     (38, 43, 'VOLUME')]}),
#  ('PREÇO: R$ 59,99', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: Produzida por um casal de mineiros que reside há vinte anos em Brasília, a Remedin guarda todas as tradições da produção artesanal, como o alambique de cobre a lenha, a fermentação natural e o envelhecimento em tóneis de carvalho.',
#   {'entities': [(71, 81, 'TEMPO'),
#     (85, 93, 'NOME_LOCAL'),
#     (97, 104, 'NOME_BEBIDA'),
#     (161, 179, 'EQUIPAMENTO_DESTILACAO'),
#     (233, 239, 'RECIPIENTE_ARMAZENAMENTO'),
#     (243, 251, 'TIPO_MADEIRA')]}),
#  ('Além da sua qualidade, a Remedin é a primeira cachaça com rótulo customizável do Brasil.',
#   {'entities': [(25, 32, 'NOME_BEBIDA'), (81, 87, 'NOME_LOCAL')]}),
#  ('Volume: 500ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Chico Mineiro Prata 600ml',
#   {'entities': [(25, 38, 'NOME_BEBIDA'),
#     (39, 44, 'CLASSIFICACAO_BEBIDA'),
#     (45, 50, 'VOLUME')]}),
#  ('PREÇO: R$ 39,90', {'entities': [(7, 15, 'PRECO')]}),
#  ('Volume: 600ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Salinas Ipê 700ml',
#   {'entities': [(25, 32, 'NOME_BEBIDA'),
#     (33, 36, 'TIPO_MADEIRA'),
#     (37, 42, 'VOLUME')]}),
#  ('PREÇO: R$ 42,99', {'entities': [(7, 15, 'PRECO')]}),
#  ('Volume: 700ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Cabaré Prata 700ml',
#   {'entities': [(25, 31, 'NOME_BEBIDA'),
#     (32, 37, 'CLASSIFICACAO_BEBIDA'),
#     (38, 43, 'VOLUME')]}),
#  ('PREÇO: R$ 45,90', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: Cachaça Cabaré Prata 700ml é Armazenada em tonéis de amendoim, esta bebida possui produção artesanal, feita completamente em propriedade familiar, desde o plantio da cana-de-açúcar até sua destilação.',
#   {'entities': [(30, 36, 'NOME_BEBIDA'),
#     (37, 42, 'CLASSIFICACAO_BEBIDA'),
#     (43, 48, 'VOLUME'),
#     (65, 71, 'RECIPIENTE_ARMAZENAMENTO'),
#     (75, 83, 'TIPO_MADEIRA')]}),
#  ('Produto totalmente brasileiro, ela possui uma cor clara e pouca interferência pelo sabor da madeira, pelo seu sabor suave é ideal para preparar aquela deliciosa caipirinha!',
#   {'entities': [(50, 55, 'CARACTERISTICA_SENSORIAL_COR'),
#     (92, 99, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (116, 121, 'CARACTERISTICA_SENSORIAL_SABOR')]}),
#  ('Após o sucesso da Cachaça Cabaré Extra Premium em parceria com os cantores Leonardo e Eduardo Costa, a Dom Tápparo apresenta a nova versão do destilado: Cachaça Cabaré Prata.',
#   {'entities': [(26, 32, 'NOME_BEBIDA'),
#     (33, 46, 'CLASSIFICACAO_BEBIDA'),
#     (75, 83, 'NOME_PESSOA'),
#     (86, 99, 'NOME_PESSOA'),
#     (103, 114, 'NOME_ORGANIZACAO'),
#     (161, 167, 'NOME_BEBIDA'),
#     (168, 173, 'CLASSIFICACAO_BEBIDA')]}),
#  ('O Engenho Dom Tápparo produz no Brasil a Cachaça Cabaré Prata, apesar de ser descansada em tonéis de amendoim, ela mantém as características da bebida pura, sua graduação alcoólica é de 38%, o que influencia no sabor e aroma mais intensos.',
#   {'entities': [(2, 21, 'NOME_ORGANIZACAO'),
#     (32, 38, 'NOME_LOCAL'),
#     (49, 55, 'NOME_BEBIDA'),
#     (56, 61, 'CLASSIFICACAO_BEBIDA'),
#     (91, 97, 'RECIPIENTE_ARMAZENAMENTO'),
#     (101, 109, 'TIPO_MADEIRA'),
#     (186, 189, 'GRADUACAO_ALCOOLICA')]}),
#  ('Graduação alcoólica 38%.', {'entities': [(20, 23, 'GRADUACAO_ALCOOLICA')]}),
#  ('Contém 700ml.', {'entities': [(7, 12, 'VOLUME')]}),
#  ('Volume: 700ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Dom Tapparo Premium Carvalho 3 anos 700ml',
#   {'entities': [(25, 36, 'NOME_BEBIDA'),
#     (37, 44, 'CLASSIFICACAO_BEBIDA'),
#     (45, 53, 'TIPO_MADEIRA'),
#     (54, 60, 'TEMPO_ARMAZENAMENTO'),
#     (61, 66, 'VOLUME')]}),
#  ('PREÇO: R$ 79,00', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: A Cachaça Dom Tápparo Extra Premium 3 Anos 700ml é uma bebida extra premium, envelhecida por oito anos em barris de carvalho.',
#   {'entities': [(32, 43, 'NOME_BEBIDA'),
#     (44, 57, 'CLASSIFICACAO_BEBIDA'),
#     (58, 64, 'TEMPO_ARMAZENAMENTO'),
#     (65, 70, 'VOLUME'),
#     (84, 97, 'CLASSIFICACAO_BEBIDA'),
#     (115, 124, 'TEMPO_ARMAZENAMENTO'),
#     (128, 134, 'RECIPIENTE_ARMAZENAMENTO'),
#     (138, 146, 'TIPO_MADEIRA')]}),
#  ('Leve, é um destilado que possui graduação alcoólica de 40%.',
#   {'entities': [(55, 58, 'GRADUACAO_ALCOOLICA')]}),
#  ('Volume: 700ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('TEMPO DE ARMAZENAMENTO: 3 anos',
#   {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}),
#  ('NOME DA CACHAÇA: Cachaça Extra Premium 6 Anos - 750ml',
#   {'entities': [(25, 38, 'CLASSIFICACAO_BEBIDA'),
#     (39, 45, 'TEMPO_ARMAZENAMENTO'),
#     (48, 53, 'VOLUME')]}),
#  ('PREÇO: R$ 169,90', {'entities': [(7, 16, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: Cachaça Extra Premium 6 Anos - 750ml',
#   {'entities': [(30, 43, 'CLASSIFICACAO_BEBIDA'),
#     (44, 50, 'TEMPO_ARMAZENAMENTO'),
#     (53, 58, 'VOLUME')]}),
#  ('Volume: 750ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('TEMPO DE ARMAZENAMENTO: 6 Anos',
#   {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}),
#  ('NOME DA CACHAÇA: Cachaça Vanderley Azevedo Premium Black Carvalho 4 Anos 700ml',
#   {'entities': [(25, 42, 'NOME_BEBIDA'),
#     (43, 50, 'CLASSIFICACAO_BEBIDA'),
#     (57, 65, 'TIPO_MADEIRA'),
#     (66, 72, 'TEMPO_ARMAZENAMENTO'),
#     (73, 78, 'VOLUME')]}),
#  ('PREÇO: R$ 309,00', {'entities': [(7, 16, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: A história da cachaça Vanderley Azevedo teve início em 1940, quando meu avô Sergio José de Araujo, em busca de diamantes no Rio Tejuco, firmou residência na cidade de Ituiutaba.',
#   {'entities': [(44, 61, 'NOME_BEBIDA'),
#     (77, 81, 'TEMPO'),
#     (98, 119, 'NOME_PESSOA'),
#     (189, 198, 'NOME_LOCAL')]}),
#  ('Vanderley Azevedo “Em 1968, fui trabalhar com meu avô no armazém e observava que o caixeiro-viajante deixava alguns tonéis com cachaça e, após 15 dias passava, para pegá-los.',
#   {'entities': [(22, 26, 'TEMPO'),
#     (116, 122, 'RECIPIENTE_ARMAZENAMENTO'),
#     (143, 150, 'TEMPO')]}),
#  ('Em 1984, meu irmão e eu compramos uma fazenda para realizarmos, nós mesmos, nossa própria produção de cachaça.',
#   {'entities': [(3, 7, 'TEMPO')]}),
#  ('Desde então, destilamos o melaço da cana de açúcar de forma artesanál.” Todo esse processo é feito com a mesma dedicação desde 1984.',
#   {'entities': [(127, 131, 'TEMPO')]}),
#  ('Em cada gota da Vanderley Azevedo está depositado todo o afeto típico do povo do interior mineiro.',
#   {'entities': [(16, 33, 'NOME_BEBIDA')]}),
#  ('Essa cachaça foi medalha de ouro no concurso mundial de Bruxelas em 2019.',
#   {'entities': [(56, 64, 'NOME_LOCAL'), (68, 72, 'TEMPO')]}),
#  ('Volume: 700ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('TEMPO DE ARMAZENAMENTO: 4 Anos',
#   {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}),
#  ('NOME DA CACHAÇA: Cachaça Asa Branca Amburana 670ml',
#   {'entities': [(25, 35, 'NOME_BEBIDA'),
#     (36, 44, 'TIPO_MADEIRA'),
#     (45, 50, 'VOLUME')]}),
#  ('PREÇO: R$ 35,90', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: De uma forma artesanal a quase 50 anos de produz a Cachaça Asa Branca em Salinas Minas Gerais, contamos com a generosidade do Criador do Universo que, nos entregou o clima apropriado e nos permite produzir o produto de Extrema Qualidade!',
#   {'entities': [(53, 60, 'TEMPO'),
#     (81, 91, 'NOME_BEBIDA'),
#     (95, 102, 'NOME_LOCAL'),
#     (103, 115, 'NOME_LOCAL')]}),
#  ('Nariz: Uma percepção levemente adocicada e uma pequena acidez lembrando frutas cítricas, com notas combinando castanha do Pará e damasco cristalizado.',
#   {'entities': [(21, 40, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (47, 61, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (72, 87, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (110, 126, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (129, 149, 'CARACTERISTICA_SENSORIAL_AROMA')]}),
#  ('Boca: A Amburana entrega um sabor amadeirado arrastando um mix de frutas cristalizadas e defumados, a impressão et?lica quase não é percebida pois sua característica invade o palato de uma forma intensa.',
#   {'entities': [(8, 16, 'TIPO_MADEIRA'),
#     (34, 44, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (66, 86, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (89, 98, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (195, 202, 'CARACTERISTICA_SENSORIAL_SABOR')]}),
#  ('Retrogosto: Podemos perceber que a impressão alcoólica praticamente se esvai após breves minutos, ficando apenas a lembrança amadeirada cítrica e frutada, pairando sobre o palato.',
#   {'entities': [(125, 135, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (136, 143, 'CARACTERISTICA_SENSORIAL_SABOR'),
#     (146, 153, 'CARACTERISTICA_SENSORIAL_SABOR')]}),
#  ('Volume: 670ml', {'entities': [(8, 13, 'VOLUME')]}),
#  ('NOME DA CACHAÇA: Cachaça Samanaú Ouro 500ml',
#   {'entities': [(25, 32, 'NOME_BEBIDA'),
#     (33, 37, 'CLASSIFICACAO_BEBIDA'),
#     (38, 43, 'VOLUME')]}),
#  ('PREÇO: R$ 59,99', {'entities': [(7, 15, 'PRECO')]}),
#  ('DESCRIÇÃO DA CACHAÇA: Cachaça Samanaú Ouro, essa cachaça é armazenada por 6 meses em barris de louro-canela.',
#   {'entities': [(30, 37, 'NOME_BEBIDA'),
#     (38, 42, 'CLASSIFICACAO_BEBIDA'),
#     (74, 81, 'TEMPO_ARMAZENAMENTO'),
#     (85, 91, 'RECIPIENTE_ARMAZENAMENTO'),
#     (95, 107, 'TIPO_MADEIRA')]}),
#  ('Características Sensoriais: ✓ Visual: densa, límpida e brilhante.',
#   {'entities': [(38, 43, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'),
#     (45, 52, 'CARACTERISTICA_SENSORIAL_COR'),
#     (55, 64, 'CARACTERISTICA_SENSORIAL_COR')]}),
#  ('✓ Olfativa: muito fina, intensa e persistente.',
#   {'entities': [(12, 22, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (24, 31, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (34, 45, 'CARACTERISTICA_SENSORIAL_AROMA')]}),
#  ('Delicadas notas florais, madeira discreta, amêndoa e especiarias, puxando para a canela.',
#   {'entities': [(10, 23, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (25, 41, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (43, 50, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (53, 64, 'CARACTERISTICA_SENSORIAL_AROMA'),
#     (81, 87, 'CARACTERISTICA_SENSORIAL_AROMA')]})]

# %% [markdown]
# ### Cross-validation do dataset para dados de treino e teste

# %% [markdown]
# https://www.kaggle.com/slavaz/spacy-ner-ensemble

# %%
from spacy.symbols import ORTH
def custom_tokenizer(nlp):
    infixes = (
        spacy.lang.char_classes.LIST_ELLIPSES
        + spacy.lang.char_classes.LIST_ICONS
        + ["\.", "\/", ":", "\(", "\)"]
        + [
            r"(?<=[0-9])[+\-\*^](?=[0-9-])",
            r"(?<=[\.])[\.](?=[\.])",
            r"(?<=[{a}{q}])\.(?=[{a}{q}])".format(
                a = spacy.lang.char_classes.ALPHA, q = spacy.lang.char_classes.CONCAT_QUOTES),
            r"(?<=[{a}]),(?=[{a}])".format(a=spacy.lang.char_classes.ALPHA),
            r"(?<=[{a}])(?:{h}|\/)(?=[{a}])".format(a=spacy.lang.char_classes.ALPHA, h=spacy.lang.char_classes.LIST_HYPHENS),
            r"(?<=[{a}])(?:{h}|\/)(?=[0-9])".format(a=spacy.lang.char_classes.ALPHA, h=spacy.lang.char_classes.LIST_HYPHENS),
            r"(?<=[0-9])(?:{h}|\/)(?=[{a}])".format(a=spacy.lang.char_classes.ALPHA, h=spacy.lang.char_classes.LIST_HYPHENS),
            r"(?<=[0-9])(?:{h}|\/|,|\.)(?=[0-9])".format(a=spacy.lang.char_classes.ALPHA, h=spacy.lang.char_classes.LIST_HYPHENS),
            r"(?<=[{a}0-9])[:<>=/](?=[{a}])".format(a=spacy.lang.char_classes.ALPHA),
            r"(?<=[{a}\"]),(?=[0-9{a}])".format(a=ALPHA),
        ]
    )
    list_quotes = ["\\'", '"', '`',
                     '‘', '´', '’', '‚', ',',
                     '„', '»', '«', '「', '」',
                     '『', '』', '（', '）', '〔',
                     '〕', '【', '】', '《', '》',
                     '〈', '〉']
    suffixes = (
        LIST_PUNCT
        + LIST_HYPHENS
        + list_quotes
        + LIST_ICONS
        + [ "\/", ":", "\(", "\)"]
        + ["'s", "'S", "’s", "’S", "—", "–"]
        + [
            r"(?<=[0-9])\+",
            # r"(?<=°[FfCcKk])\.",
            r"(?<=[0-9])(?:{c})".format(c=CURRENCY),
            # r"(?<=[0-9])(?:{u})".format(u=UNITS),
            r"(?<=[0-9a-z(?:{q})])\.".format(
            al=ALPHA_LOWER, q=CONCAT_QUOTES),
            r"(?<=[{au}])\.".format(au=ALPHA_UPPER),
        ] 
    )
    
    prefixes = (
        LIST_PUNCT
        + [ "\/", ":", "\(", "\)"]
        + LIST_HYPHENS
        + list_quotes
        + LIST_CURRENCY
        + LIST_ICONS
    )
    # print(prefixes)

    infix_re = spacy.util.compile_infix_regex(infixes)
    suffix_re = spacy.util.compile_suffix_regex(suffixes)
    prefix_re = spacy.util.compile_prefix_regex(prefixes)
    # suffix_re = re.compile(r'''\.[\]\)"']$''')
    custom = Tokenizer(nlp.vocab, prefix_search=prefix_re.search,
                                suffix_search=suffix_re.search,
                                infix_finditer=infix_re.finditer,
                                token_match=nlp.tokenizer.token_match,
                                rules=None)
    special_case = [{ORTH: "."}, {ORTH: "."}, {ORTH: "."}]        # Adding special case rule
    custom.add_special_case("...", special_case)
    return custom
custom_tokenizer(nlp)

# %%
# Alterando Tokenizador
from spacy.tokenizer import Tokenizer
test_text = 'Premiações : 1º Lugar na ... "Exposição",aa 190% a-a do Formiga-MG”,) da arte a$moderna/1922 1º Lugar no concurso de cachaça 1111 2003 de qualidade Hotel Sofitel Rio de Janeiro/2005 E destaque entre as 10 melhores cachaças envelhecida na Expocachaça São Paulo(Mercado Municipal) 2011.'
# test_text = "ANÁLISE DO CACHACIER: De cor amarelo-clara, possui uma mescla de aromas florais e adocicados."
# test_text = "Premiações : 1º Lugar na Exposição do Centenário,semana da arte moderna/1922 1º Lugar no concurso de cachaça de qualidade Hotel Sofitel Rio de Janeiro/2005 E destaque entre as 10 melhores cachaças envelhecida na Expocachaça São Paulo(Mercado Municipal) 2011."
# test_text = "PREÇO: R$ 35,00"
doc = nlp(test_text)

print("Default tokenized text",end=' : ')
for token in doc:
    print(token,end=', ')



nlp.tokenizer = custom_tokenizer(nlp)
doc = nlp(test_text)

print("\nAFTER tokenized text",end=' : ')
tok_exp = nlp.tokenizer.explain(test_text)

for t in tok_exp:
    print(t[1], "\t", t[0])


# with open("/home/arthur/Documentos/IC/git/ProjetoMestrado/DataSets/Dados_Utilizados_Para_RotulacaoManual.txt", "r", encoding='utf-8') as text_file:
#     textos = text_file.read().splitlines()
# print("Quantidade de linhas da base:", len(textos))
# for test_text in textos:
#     doc = nlp(test_text)
#     with open("tokensBySpacyFix.txt","a") as file:
#         for token in doc:
#                 print(token)
#                 file.write(f"{token}\n")


print("\n\n")
print()
# tok_exp = nlp.tokenizer.explain(test_text)
# for t in tok_exp:
#     print(t[1], "\t", t[0])

# print(list(nlp.Defaults.infixes))


# with open("/home/arthur/Documentos/IC/git/ProjetoMestrado/DataSets/Dados_Utilizados_Para_RotulacaoManual.txt", "r", encoding='utf-8') as text_file:
#     textos = text_file.read().splitlines()
# print("Quantidade de linhas da base:", len(textos))
# for test_text in textos:
#     tok_exp = nlp.tokenizer.explain(test_text)
# # for t in tok_exp:
# #     print(t[1], "\t", t[0])
#     with open("tokensBySpacy.txt","a") as file:
#         for t in tok_exp:
#             print(t[1], "\t", t[0])
#             file.write(f"{t[1]}\t{t[0]}\n")
# Out:
# Default tokenized text : Premiações, :, 1º, Lugar, na, ..., ", Exposição",aa, 190, %, a-a, do, Formiga-MG, ”, ,, ), da, arte, a$, moderna/1922, 1º, Lugar, no, concurso, de, cachaça, 1111, 2003, de, qualidade, Hotel, Sofitel, Rio, de, Janeiro/2005, E, destaque, entre, as, 10, melhores, cachaças, envelhecida, na, Expocachaça, São, Paulo(Mercado, Municipal, ), 2011, .,
# AFTER tokenized text : Premiações 	 TOKEN
# : 	 PREFIX
# 1º 	 TOKEN
# Lugar 	 TOKEN
# na 	 TOKEN
# . 	 SPECIAL-1
# . 	 SPECIAL-2
# . 	 SPECIAL-3
# " 	 PREFIX
# Exposição" 	 TOKEN
# , 	 INFIX
# aa 	 TOKEN
# 190% 	 TOKEN
# a 	 TOKEN
# - 	 INFIX
# a 	 TOKEN
# do 	 TOKEN
# Formiga 	 TOKEN
# - 	 INFIX
# MG” 	 TOKEN
# , 	 SUFFIX
# ) 	 SUFFIX
# da 	 TOKEN
# arte 	 TOKEN
# a$moderna 	 TOKEN
# / 	 INFIX
# 1922 	 TOKEN
# 1º 	 TOKEN
# Lugar 	 TOKEN
# no 	 TOKEN
# concurso 	 TOKEN
# de 	 TOKEN
# cachaça 	 TOKEN
# 1111 	 TOKEN
# 2003 	 TOKEN
# de 	 TOKEN
# qualidade 	 TOKEN
# Hotel 	 TOKEN
# Sofitel 	 TOKEN
# Rio 	 TOKEN
# de 	 TOKEN
# Janeiro 	 TOKEN
# / 	 INFIX
# 2005 	 TOKEN
# E 	 TOKEN
# destaque 	 TOKEN
# entre 	 TOKEN
# as 	 TOKEN
# 10 	 TOKEN
# melhores 	 TOKEN
# cachaças 	 TOKEN
# envelhecida 	 TOKEN
# na 	 TOKEN
# Expocachaça 	 TOKEN
# São 	 TOKEN
# Paulo 	 TOKEN
# ( 	 INFIX
# Mercado 	 TOKEN
# Municipal 	 TOKEN
# ) 	 SUFFIX
# 2011 	 TOKEN
# . 	 SUFFIX

# %%
print(list(nlp.Defaults.infixes))

# %%
print(list(infixes))
# print(list(nlp.p))

# %%
# Obtendo o componente do pipeline para trabalhar com reconhecimentos de entidades nomeadas
ner = nlp.get_pipe('ner')

# Adicionando as categorias de entidade nomeada ao pipeline 'ner'
ner.add_label('CARACTERISTICA_SENSORIAL_AROMA')
ner.add_label('CARACTERISTICA_SENSORIAL_CONSISTÊNCIA')
ner.add_label('CARACTERISTICA_SENSORIAL_SABOR')
ner.add_label('CARACTERISTICA_SENSORIAL_COR')
ner.add_label('RECIPIENTE_ARMAZENAMENTO')
ner.add_label('EQUIPAMENTO_DESTILACAO')
ner.add_label('CLASSIFICACAO_BEBIDA')
ner.add_label('TEMPO_ARMAZENAMENTO')
ner.add_label('GRADUACAO_ALCOOLICA')
ner.add_label('TIPO_MADEIRA')
ner.add_label('NOME_BEBIDA')
ner.add_label('VOLUME')
ner.add_label('NOME_LOCAL')
ner.add_label('NOME_ORGANIZACAO')
ner.add_label('NOME_PESSOA')
ner.add_label('PRECO')
ner.add_label('TEMPO')
# Out:
# 1

# %% [raw]
# # outra maneira mais rápida de adicionar as categorias de entidades ao 'ner'
#
# ner = nlp.get_pipe('ner')
#
# for texto, annotations in TRAIN_DATA:
#     for ent in annotations.get("entities"):
#         ner.add_label(ent[2])
#         print(ent[2])

# %%
#verificando as categorias de entidades nomeadas contidas no pipeline
print("Categorias de entidade que o modelo contém:", '\n\n', ner.label_data)
# Out:
# Categorias de entidade que o modelo contém:
#
#  {0: Counter(), 1: Counter({'LOC': 137478, 'PER': 65030, 'MISC': 38659, 'ORG': 25003, 'CARACTERISTICA_SENSORIAL_AROMA': -1, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA': -2, 'CARACTERISTICA_SENSORIAL_SABOR': -3, 'CARACTERISTICA_SENSORIAL_COR': -4, 'RECIPIENTE_ARMAZENAMENTO': -5, 'EQUIPAMENTO_DESTILACAO': -6, 'CLASSIFICACAO_BEBIDA': -7, 'TEMPO_ARMAZENAMENTO': -8, 'GRADUACAO_ALCOOLICA': -9, 'TIPO_MADEIRA': -10, 'NOME_BEBIDA': -11, 'VOLUME': -12, 'NOME_LOCAL': -13, 'NOME_ORGANIZACAO': -14, 'NOME_PESSOA': -15, 'PRECO': -16, 'TEMPO': -17}), 2: Counter({'LOC': 137478, 'PER': 65030, 'MISC': 38659, 'ORG': 25003, 'CARACTERISTICA_SENSORIAL_AROMA': -1, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA': -2, 'CARACTERISTICA_SENSORIAL_SABOR': -3, 'CARACTERISTICA_SENSORIAL_COR': -4, 'RECIPIENTE_ARMAZENAMENTO': -5, 'EQUIPAMENTO_DESTILACAO': -6, 'CLASSIFICACAO_BEBIDA': -7, 'TEMPO_ARMAZENAMENTO': -8, 'GRADUACAO_ALCOOLICA': -9, 'TIPO_MADEIRA': -10, 'NOME_BEBIDA': -11, 'VOLUME': -12, 'NOME_LOCAL': -13, 'NOME_ORGANIZACAO': -14, 'NOME_PESSOA': -15, 'PRECO': -16, 'TEMPO': -17}), 3: Counter({'LOC': 137478, 'PER': 65030, 'MISC': 38659, 'ORG': 25003, 'CARACTERISTICA_SENSORIAL_AROMA': -1, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA': -2, 'CARACTERISTICA_SENSORIAL_SABOR': -3, 'CARACTERISTICA_SENSORIAL_COR': -4, 'RECIPIENTE_ARMAZENAMENTO': -5, 'EQUIPAMENTO_DESTILACAO': -6, 'CLASSIFICACAO_BEBIDA': -7, 'TEMPO_ARMAZENAMENTO': -8, 'GRADUACAO_ALCOOLICA': -9, 'TIPO_MADEIRA': -10, 'NOME_BEBIDA': -11, 'VOLUME': -12, 'NOME_LOCAL': -13, 'NOME_ORGANIZACAO': -14, 'NOME_PESSOA': -15, 'PRECO': -16, 'TEMPO': -17}), 4: Counter({'LOC': 137478, 'PER': 65030, 'MISC': 38659, 'ORG': 25003, '': 1, 'CARACTERISTICA_SENSORIAL_AROMA': -1, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA': -2, 'CARACTERISTICA_SENSORIAL_SABOR': -3, 'CARACTERISTICA_SENSORIAL_COR': -4, 'RECIPIENTE_ARMAZENAMENTO': -5, 'EQUIPAMENTO_DESTILACAO': -6, 'CLASSIFICACAO_BEBIDA': -7, 'TEMPO_ARMAZENAMENTO': -8, 'GRADUACAO_ALCOOLICA': -9, 'TIPO_MADEIRA': -10, 'NOME_BEBIDA': -11, 'VOLUME': -12, 'NOME_LOCAL': -13, 'NOME_ORGANIZACAO': -14, 'NOME_PESSOA': -15, 'PRECO': -16, 'TEMPO': -17}), 5: Counter({'': 1})}

# %%
# Obter os nomes dos componentes que queremos desativar durante o treinamento

#pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
#unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']

# %% [markdown]
# ### Treinando o modelo de reconhecimento de entidades nomeadas

# %%
# iniciar o ciclo de treinamento, apenas treinando NER

epochs = 10
optimizer = nlp.create_optimizer()
#optimizer = nlp.resume_training()
#optimizer = nlp.begin_training()

with nlp.disable_pipes(*unaffected_pipes), warnings.catch_warnings():
    warnings.filterwarnings("once", category=UserWarning, module='spacy')
    print(date.datetime.now())
    sizes = compounding(4.0, 32.0, 1.001)
    
    # agrupe os exemplos usando o minibatc do spaCy
    for epoch in range(epochs):
        examples = TRAIN_DATA
        random.shuffle(examples)
        batches = minibatch(examples, size=sizes)
        losses = {}
        
        for batch in batches:
            texts, annotations = zip(*batch)
            example = []
            # Atualize o modelo com a iteração de cada texto
            for i in range(len(texts)):
                doc = nlp.make_doc(texts[i])
                example.append(Example.from_dict(doc, annotations[i]))
                # Update the model
                nlp.update(example, drop=0.35, losses=losses,sgd=optimizer)
        print("Losses ({}/{})" .format(epoch + 1, epochs), '-', date.datetime.now(), losses)
# Out:
# 2022-03-21 20:55:56.431104
# /home/arthur/.local/lib/python3.8/site-packages/spacy/training/iob_utils.py:141: UserWarning: [W030] Some entities could not be aligned in the text "PREMIOS: 2017 - 2º Lugar na 27ª Edição Expocachaça..." with entities "[(9, 13, 'TEMPO'), (53, 67, 'NOME_LOCAL'), (68, 70...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses (1/1) - 2022-03-21 21:11:45.572053 {'ner': 52821.746543047004}

# %% [markdown]
# ## Testando o Modelo

# %%
# Exemplo using o display sentence involving original entities
spacy.displacy.render(nlp("A Bacuri é uma cachaça, tem um sabor tropical que vai aumentar o seu ânimo e envolvê-lo em uma onda de puro prazer. É armazenada em barris de jequitibá"), style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bacuri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NOME_BEBIDA</span>
# </mark>
#  é uma cachaça, tem um sabor tropical que vai aumentar o seu ânimo e envolvê-lo em uma onda de puro prazer. É armazenada em
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     barris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">RECIPIENTE_ARMAZENAMENTO</span>
# </mark>
#  de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jequitibá
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIPO_MADEIRA</span>
# </mark>
# </div></span>

# %% [markdown]
# ### Carregando Dados para Teste

# %%
dados_Teste = [('A Cachaça Serra Limpa Prata 355ml é uma bebida armazenada por seis meses em tonéis de inox. Robusta. É uma das únicas Cachaças Artesanais cem porcento orgânicas do Brasil. Contém 50% de graduação alcoolia',
  {'entities': [(76, 91, 'RECIPIENTE_ARMAZENAMENTO')]}),
  
  ('A Cachaça Minha Deusa Vale Verde Prata 1000ml é uma bebida armazenada por um ano em tonéis de grápia, o que realça o aroma de cana-de-açúcar. Leve,. De sabor suave e marcante, é perfeita para o preparo de drinks e coquetéis.',
  {'entities': [(84, 100, 'RECIPIENTE_ARMAZENAMENTO')]}),

  ('Cachaça Mineirinha 355ml é uma edição especial das Cachaças Dona Beja, de Perdizes, Minas Gerais. Armazenada por cinco anos em barris de jequitiba. Chama a atenção a embalagem da bebida, que é envasada em garrafas de louça que imitam a cana-de-açúcar.',
  {'entities': [(127, 147, 'RECIPIENTE_ARMAZENAMENTO')]}),
 
  ('Três Corações é uma bebida armazenada por 2 anos em jequitibá. Robusta e com aroma doce', 
  {'entities':[(52, 61, 'RECIPIENTE_ARMAZENAMENTO')]})          
    ]

# %% [markdown]
# ### Avaliação do Modelo

# %%
# Compara item por item o que foi classificado pelo modelo e a classifcação correta(manual)

#nlp = spacy.load(output_dir)
examples = []

for text, annots in TEST_DATA:
    print(f'Manual Anotation: {annots}')
    doc = nlp(text)
    #doc = nlp.make_doc(text)
    #pacy.displacy.render(nlp(text))
    
    for item in doc.ents:
        print('Model prediction: ', 'entities: ', [(item.start_char, item.end_char,item.label_)])
                
    examples.append(Example.from_dict(doc, annots)) 
    #print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Manual Anotation: {'entities': [(10, 17, 'NOME_BEBIDA'), (18, 26, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(10, 17, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(18, 26, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(29, 36, 'NOME_BEBIDA'), (53, 59, 'RECIPIENTE_ARMAZENAMENTO'), (63, 71, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(29, 36, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(53, 59, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(63, 71, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(118, 123, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(136, 147, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Manual Anotation: {'entities': [(14, 20, 'RECIPIENTE_ARMAZENAMENTO'), (24, 32, 'TIPO_MADEIRA'), (98, 115, 'CARACTERISTICA_SENSORIAL_SABOR'), (117, 125, 'CARACTERISTICA_SENSORIAL_SABOR'), (128, 135, 'CARACTERISTICA_SENSORIAL_SABOR')]}
# Model prediction:  entities:  [(14, 20, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(24, 32, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(98, 115, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(117, 125, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(128, 135, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Manual Anotation: {'entities': [(8, 15, 'NOME_LOCAL'), (18, 20, 'NOME_LOCAL'), (30, 38, 'TIPO_MADEIRA'), (55, 61, 'TEMPO_ARMAZENAMENTO')]}
# Model prediction:  entities:  [(8, 15, 'NOME_LOCAL')]
# Model prediction:  entities:  [(18, 20, 'NOME_LOCAL')]
# Model prediction:  entities:  [(30, 38, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(55, 61, 'TEMPO_ARMAZENAMENTO')]
# Manual Anotation: {'entities': [(11, 14, 'GRADUACAO_ALCOOLICA'), (23, 28, 'VOLUME')]}
# Model prediction:  entities:  [(11, 14, 'GRADUACAO_ALCOOLICA')]
# Model prediction:  entities:  [(23, 28, 'VOLUME')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(21, 24, 'GRADUACAO_ALCOOLICA')]}
# Model prediction:  entities:  [(21, 24, 'GRADUACAO_ALCOOLICA')]
# Manual Anotation: {'entities': [(29, 37, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(29, 37, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(19, 26, 'NOME_LOCAL'), (29, 31, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(19, 26, 'NOME_LOCAL')]
# Model prediction:  entities:  [(29, 31, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}
# Model prediction:  entities:  [(24, 30, 'TEMPO_ARMAZENAMENTO')]
# Manual Anotation: {'entities': [(25, 57, 'NOME_BEBIDA'), (66, 71, 'VOLUME')]}
# Model prediction:  entities:  [(25, 35, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(66, 71, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(32, 64, 'NOME_BEBIDA'), (65, 70, 'VOLUME'), (124, 130, 'NOME_LOCAL'), (146, 167, 'NOME_LOCAL'), (172, 184, 'NOME_LOCAL'), (196, 206, 'NOME_LOCAL'), (209, 225, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(32, 64, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(65, 70, 'VOLUME')]
# Model prediction:  entities:  [(124, 130, 'NOME_LOCAL')]
# Model prediction:  entities:  [(146, 167, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(172, 184, 'NOME_ORGANIZACAO')]
# Model prediction:  entities:  [(209, 225, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(14, 28, 'RECIPIENTE_ARMAZENAMENTO'), (33, 43, 'TEMPO_ARMAZENAMENTO'), (75, 78, 'GRADUACAO_ALCOOLICA')]}
# Model prediction:  entities:  [(14, 28, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(33, 43, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(75, 78, 'GRADUACAO_ALCOOLICA')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 35, 'NOME_BEBIDA'), (36, 41, 'VOLUME')]}
# Model prediction:  entities:  [(36, 41, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(34, 44, 'NOME_BEBIDA'), (45, 53, 'TIPO_MADEIRA'), (74, 83, 'CARACTERISTICA_SENSORIAL_AROMA'), (89, 98, 'CARACTERISTICA_SENSORIAL_COR'), (101, 108, 'CARACTERISTICA_SENSORIAL_COR')]}
# Model prediction:  entities:  [(45, 53, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(89, 98, 'CARACTERISTICA_SENSORIAL_COR')]
# Model prediction:  entities:  [(101, 123, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Manual Anotation: {'entities': [(14, 23, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'), (28, 55, 'CARACTERISTICA_SENSORIAL_SABOR')]}
# Manual Anotation: {'entities': [(17, 23, 'TEMPO_ARMAZENAMENTO'), (27, 33, 'RECIPIENTE_ARMAZENAMENTO'), (37, 45, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(17, 23, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(27, 33, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(37, 45, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(22, 25, 'GRADUACAO_ALCOOLICA')]}
# Model prediction:  entities:  [(22, 25, 'GRADUACAO_ALCOOLICA')]
# Manual Anotation: {'entities': [(45, 53, 'NOME_LOCAL'), (55, 57, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(45, 53, 'NOME_LOCAL')]
# Model prediction:  entities:  [(55, 57, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 46, 'NOME_BEBIDA'), (47, 51, 'CLASSIFICACAO_BEBIDA'), (52, 57, 'VOLUME')]}
# Model prediction:  entities:  [(25, 46, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(47, 51, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(52, 57, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(32, 36, 'CLASSIFICACAO_BEBIDA'), (40, 53, 'NOME_ORGANIZACAO'), (123, 127, 'TEMPO'), (194, 228, 'NOME_ORGANIZACAO')]}
# Model prediction:  entities:  [(32, 53, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(123, 127, 'TEMPO')]
# Model prediction:  entities:  [(194, 228, 'NOME_ORGANIZACAO')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 31, 'NOME_BEBIDA'), (32, 37, 'CLASSIFICACAO_BEBIDA'), (38, 43, 'VOLUME')]}
# Model prediction:  entities:  [(25, 31, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(32, 37, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(38, 43, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(32, 38, 'NOME_BEBIDA'), (79, 95, 'NOME_LOCAL'), (212, 220, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(32, 38, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(79, 95, 'NOME_LOCAL')]
# Model prediction:  entities:  [(212, 220, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(14, 28, 'NOME_ORGANIZACAO'), (199, 205, 'CARACTERISTICA_SENSORIAL_AROMA'), (231, 237, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(14, 28, 'NOME_ORGANIZACAO')]
# Model prediction:  entities:  [(231, 237, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 41, 'NOME_BEBIDA'), (42, 50, 'TIPO_MADEIRA'), (51, 56, 'VOLUME')]}
# Model prediction:  entities:  [(25, 41, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(42, 50, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(51, 56, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 16, 'PRECO')]}
# Model prediction:  entities:  [(7, 16, 'PRECO')]
# Manual Anotation: {'entities': [(32, 42, 'CARACTERISTICA_SENSORIAL_COR'), (44, 54, 'CARACTERISTICA_SENSORIAL_COR')]}
# Manual Anotation: {'entities': [(19, 35, 'CARACTERISTICA_SENSORIAL_AROMA'), (59, 70, 'CARACTERISTICA_SENSORIAL_AROMA'), (76, 82, 'CARACTERISTICA_SENSORIAL_AROMA'), (85, 93, 'CARACTERISTICA_SENSORIAL_AROMA')]}
# Model prediction:  entities:  [(19, 35, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(40, 70, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(76, 82, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(85, 93, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Manual Anotation: {'entities': [(6, 11, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'), (12, 21, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'), (50, 63, 'CARACTERISTICA_SENSORIAL_SABOR'), (66, 83, 'CARACTERISTICA_SENSORIAL_SABOR')]}
# Model prediction:  entities:  [(6, 21, 'NOME_ORGANIZACAO')]
# Model prediction:  entities:  [(66, 83, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Manual Anotation: {'entities': [(12, 26, 'CARACTERISTICA_SENSORIAL_SABOR'), (27, 38, 'CARACTERISTICA_SENSORIAL_SABOR'), (41, 49, 'CARACTERISTICA_SENSORIAL_SABOR')]}
# Model prediction:  entities:  [(16, 38, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(41, 49, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Manual Anotation: {'entities': [(8, 22, 'NOME_LOCAL'), (25, 27, 'NOME_LOCAL'), (36, 44, 'TIPO_MADEIRA'), (46, 54, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(8, 22, 'NOME_LOCAL')]
# Model prediction:  entities:  [(25, 27, 'NOME_LOCAL')]
# Model prediction:  entities:  [(36, 44, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(46, 54, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(30, 36, 'RECIPIENTE_ARMAZENAMENTO'), (40, 48, 'TIPO_MADEIRA'), (50, 58, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(30, 36, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(40, 48, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(50, 58, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(21, 24, 'GRADUACAO_ALCOOLICA'), (65, 70, 'VOLUME')]}
# Model prediction:  entities:  [(21, 24, 'GRADUACAO_ALCOOLICA')]
# Model prediction:  entities:  [(65, 70, 'VOLUME')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 41, 'NOME_BEBIDA'), (53, 58, 'VOLUME')]}
# Model prediction:  entities:  [(25, 41, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(53, 58, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 16, 'PRECO')]}
# Model prediction:  entities:  [(7, 16, 'PRECO')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 32, 'NOME_BEBIDA'), (33, 37, 'CLASSIFICACAO_BEBIDA'), (38, 43, 'VOLUME')]}
# Model prediction:  entities:  [(25, 32, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(33, 37, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(38, 43, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(71, 81, 'TEMPO'), (85, 93, 'NOME_LOCAL'), (97, 104, 'NOME_BEBIDA'), (161, 179, 'EQUIPAMENTO_DESTILACAO'), (233, 239, 'RECIPIENTE_ARMAZENAMENTO'), (243, 251, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(71, 81, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(85, 93, 'NOME_LOCAL')]
# Model prediction:  entities:  [(161, 179, 'EQUIPAMENTO_DESTILACAO')]
# Model prediction:  entities:  [(233, 239, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(243, 251, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(25, 32, 'NOME_BEBIDA'), (81, 87, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(81, 87, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 38, 'NOME_BEBIDA'), (39, 44, 'CLASSIFICACAO_BEBIDA'), (45, 50, 'VOLUME')]}
# Model prediction:  entities:  [(25, 38, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(39, 44, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(45, 50, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 32, 'NOME_BEBIDA'), (33, 36, 'TIPO_MADEIRA'), (37, 42, 'VOLUME')]}
# Model prediction:  entities:  [(25, 32, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(33, 36, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(37, 42, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 31, 'NOME_BEBIDA'), (32, 37, 'CLASSIFICACAO_BEBIDA'), (38, 43, 'VOLUME')]}
# Model prediction:  entities:  [(25, 31, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(32, 37, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(38, 43, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(30, 36, 'NOME_BEBIDA'), (37, 42, 'CLASSIFICACAO_BEBIDA'), (43, 48, 'VOLUME'), (65, 71, 'RECIPIENTE_ARMAZENAMENTO'), (75, 83, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(30, 36, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(37, 42, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(43, 48, 'VOLUME')]
# Model prediction:  entities:  [(65, 71, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(75, 83, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(50, 55, 'CARACTERISTICA_SENSORIAL_COR'), (92, 99, 'CARACTERISTICA_SENSORIAL_SABOR'), (116, 121, 'CARACTERISTICA_SENSORIAL_SABOR')]}
# Model prediction:  entities:  [(50, 55, 'CARACTERISTICA_SENSORIAL_COR')]
# Model prediction:  entities:  [(58, 99, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(116, 121, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(144, 160, 'CARACTERISTICA_SENSORIAL_COR')]
# Manual Anotation: {'entities': [(26, 32, 'NOME_BEBIDA'), (33, 46, 'CLASSIFICACAO_BEBIDA'), (75, 83, 'NOME_PESSOA'), (86, 99, 'NOME_PESSOA'), (103, 114, 'NOME_ORGANIZACAO'), (161, 167, 'NOME_BEBIDA'), (168, 173, 'CLASSIFICACAO_BEBIDA')]}
# Model prediction:  entities:  [(26, 32, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(33, 46, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(75, 83, 'NOME_PESSOA')]
# Model prediction:  entities:  [(86, 99, 'NOME_PESSOA')]
# Model prediction:  entities:  [(103, 114, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(161, 167, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(168, 173, 'CLASSIFICACAO_BEBIDA')]
# Manual Anotation: {'entities': [(2, 21, 'NOME_ORGANIZACAO'), (32, 38, 'NOME_LOCAL'), (49, 55, 'NOME_BEBIDA'), (56, 61, 'CLASSIFICACAO_BEBIDA'), (91, 97, 'RECIPIENTE_ARMAZENAMENTO'), (101, 109, 'TIPO_MADEIRA'), (186, 189, 'GRADUACAO_ALCOOLICA')]}
# Model prediction:  entities:  [(2, 21, 'NOME_ORGANIZACAO')]
# Model prediction:  entities:  [(32, 38, 'NOME_LOCAL')]
# Model prediction:  entities:  [(49, 55, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(56, 61, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(91, 97, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(101, 109, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(186, 189, 'GRADUACAO_ALCOOLICA')]
# Manual Anotation: {'entities': [(20, 23, 'GRADUACAO_ALCOOLICA')]}
# Model prediction:  entities:  [(20, 23, 'GRADUACAO_ALCOOLICA')]
# Manual Anotation: {'entities': [(7, 12, 'VOLUME')]}
# Model prediction:  entities:  [(7, 12, 'VOLUME')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 36, 'NOME_BEBIDA'), (37, 44, 'CLASSIFICACAO_BEBIDA'), (45, 53, 'TIPO_MADEIRA'), (54, 60, 'TEMPO_ARMAZENAMENTO'), (61, 66, 'VOLUME')]}
# Model prediction:  entities:  [(25, 36, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(37, 44, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(45, 53, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(54, 60, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(61, 66, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(32, 43, 'NOME_BEBIDA'), (44, 57, 'CLASSIFICACAO_BEBIDA'), (58, 64, 'TEMPO_ARMAZENAMENTO'), (65, 70, 'VOLUME'), (84, 97, 'CLASSIFICACAO_BEBIDA'), (115, 124, 'TEMPO_ARMAZENAMENTO'), (128, 134, 'RECIPIENTE_ARMAZENAMENTO'), (138, 146, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(32, 43, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(44, 57, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(58, 64, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(65, 70, 'VOLUME')]
# Model prediction:  entities:  [(84, 97, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(115, 124, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(128, 134, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(138, 146, 'TIPO_MADEIRA')]
# Manual Anotation: {'entities': [(55, 58, 'GRADUACAO_ALCOOLICA')]}
# Model prediction:  entities:  [(55, 58, 'GRADUACAO_ALCOOLICA')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}
# Model prediction:  entities:  [(24, 30, 'TEMPO_ARMAZENAMENTO')]
# Manual Anotation: {'entities': [(25, 38, 'CLASSIFICACAO_BEBIDA'), (39, 45, 'TEMPO_ARMAZENAMENTO'), (48, 53, 'VOLUME')]}
# Model prediction:  entities:  [(25, 38, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(39, 45, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(48, 53, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 16, 'PRECO')]}
# Model prediction:  entities:  [(7, 16, 'PRECO')]
# Manual Anotation: {'entities': [(30, 43, 'CLASSIFICACAO_BEBIDA'), (44, 50, 'TEMPO_ARMAZENAMENTO'), (53, 58, 'VOLUME')]}
# Model prediction:  entities:  [(30, 43, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(44, 50, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(53, 58, 'VOLUME')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}
# Model prediction:  entities:  [(24, 30, 'TEMPO_ARMAZENAMENTO')]
# Manual Anotation: {'entities': [(25, 42, 'NOME_BEBIDA'), (43, 50, 'CLASSIFICACAO_BEBIDA'), (57, 65, 'TIPO_MADEIRA'), (66, 72, 'TEMPO_ARMAZENAMENTO'), (73, 78, 'VOLUME')]}
# Model prediction:  entities:  [(25, 42, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(43, 56, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(57, 65, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(66, 67, 'TEMPO')]
# Model prediction:  entities:  [(73, 78, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 16, 'PRECO')]}
# Model prediction:  entities:  [(7, 16, 'PRECO')]
# Manual Anotation: {'entities': [(44, 61, 'NOME_BEBIDA'), (77, 81, 'TEMPO'), (98, 119, 'NOME_PESSOA'), (189, 198, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(44, 61, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(77, 81, 'TEMPO')]
# Model prediction:  entities:  [(98, 119, 'NOME_PESSOA')]
# Model prediction:  entities:  [(189, 198, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(22, 26, 'TEMPO'), (116, 122, 'RECIPIENTE_ARMAZENAMENTO'), (143, 150, 'TEMPO')]}
# Model prediction:  entities:  [(0, 17, 'NOME_PESSOA')]
# Model prediction:  entities:  [(22, 26, 'TEMPO')]
# Model prediction:  entities:  [(116, 122, 'RECIPIENTE_ARMAZENAMENTO')]
# Model prediction:  entities:  [(143, 150, 'TEMPO')]
# Manual Anotation: {'entities': [(3, 7, 'TEMPO')]}
# Model prediction:  entities:  [(3, 7, 'TEMPO')]
# Manual Anotation: {'entities': [(127, 131, 'TEMPO')]}
# Model prediction:  entities:  [(127, 131, 'TEMPO')]
# Manual Anotation: {'entities': [(16, 33, 'NOME_BEBIDA')]}
# Model prediction:  entities:  [(16, 33, 'NOME_BEBIDA')]
# Manual Anotation: {'entities': [(56, 64, 'NOME_LOCAL'), (68, 72, 'TEMPO')]}
# Model prediction:  entities:  [(56, 64, 'NOME_LOCAL')]
# Model prediction:  entities:  [(68, 72, 'TEMPO')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(24, 30, 'TEMPO_ARMAZENAMENTO')]}
# Model prediction:  entities:  [(24, 30, 'TEMPO_ARMAZENAMENTO')]
# Manual Anotation: {'entities': [(25, 35, 'NOME_BEBIDA'), (36, 44, 'TIPO_MADEIRA'), (45, 50, 'VOLUME')]}
# Model prediction:  entities:  [(25, 35, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(36, 44, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(45, 50, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(53, 60, 'TEMPO'), (81, 91, 'NOME_BEBIDA'), (95, 102, 'NOME_LOCAL'), (103, 115, 'NOME_LOCAL')]}
# Model prediction:  entities:  [(81, 91, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(95, 102, 'NOME_LOCAL')]
# Model prediction:  entities:  [(103, 115, 'NOME_LOCAL')]
# Manual Anotation: {'entities': [(21, 40, 'CARACTERISTICA_SENSORIAL_AROMA'), (47, 61, 'CARACTERISTICA_SENSORIAL_AROMA'), (72, 87, 'CARACTERISTICA_SENSORIAL_AROMA'), (110, 126, 'CARACTERISTICA_SENSORIAL_AROMA'), (129, 149, 'CARACTERISTICA_SENSORIAL_AROMA')]}
# Model prediction:  entities:  [(21, 40, 'CARACTERISTICA_SENSORIAL_COR')]
# Model prediction:  entities:  [(47, 61, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(72, 87, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(93, 126, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(137, 149, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Manual Anotation: {'entities': [(8, 16, 'TIPO_MADEIRA'), (34, 44, 'CARACTERISTICA_SENSORIAL_SABOR'), (66, 86, 'CARACTERISTICA_SENSORIAL_SABOR'), (89, 98, 'CARACTERISTICA_SENSORIAL_SABOR'), (195, 202, 'CARACTERISTICA_SENSORIAL_SABOR')]}
# Model prediction:  entities:  [(8, 16, 'TIPO_MADEIRA')]
# Model prediction:  entities:  [(34, 44, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(66, 86, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(89, 98, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(195, 202, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Manual Anotation: {'entities': [(125, 135, 'CARACTERISTICA_SENSORIAL_SABOR'), (136, 143, 'CARACTERISTICA_SENSORIAL_SABOR'), (146, 153, 'CARACTERISTICA_SENSORIAL_SABOR')]}
# Model prediction:  entities:  [(125, 135, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(146, 153, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Manual Anotation: {'entities': [(8, 13, 'VOLUME')]}
# Model prediction:  entities:  [(8, 13, 'VOLUME')]
# Manual Anotation: {'entities': [(25, 32, 'NOME_BEBIDA'), (33, 37, 'CLASSIFICACAO_BEBIDA'), (38, 43, 'VOLUME')]}
# Model prediction:  entities:  [(25, 32, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(33, 37, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(38, 43, 'VOLUME')]
# Manual Anotation: {'entities': [(7, 15, 'PRECO')]}
# Model prediction:  entities:  [(7, 15, 'PRECO')]
# Manual Anotation: {'entities': [(30, 37, 'NOME_BEBIDA'), (38, 42, 'CLASSIFICACAO_BEBIDA'), (74, 81, 'TEMPO_ARMAZENAMENTO'), (85, 91, 'RECIPIENTE_ARMAZENAMENTO'), (95, 107, 'TIPO_MADEIRA')]}
# Model prediction:  entities:  [(30, 37, 'NOME_BEBIDA')]
# Model prediction:  entities:  [(38, 42, 'CLASSIFICACAO_BEBIDA')]
# Model prediction:  entities:  [(74, 81, 'TEMPO_ARMAZENAMENTO')]
# Model prediction:  entities:  [(85, 107, 'RECIPIENTE_ARMAZENAMENTO')]
# Manual Anotation: {'entities': [(38, 43, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA'), (45, 52, 'CARACTERISTICA_SENSORIAL_COR'), (55, 64, 'CARACTERISTICA_SENSORIAL_COR')]}
# Model prediction:  entities:  [(38, 43, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA')]
# Model prediction:  entities:  [(45, 52, 'CARACTERISTICA_SENSORIAL_COR')]
# Model prediction:  entities:  [(55, 64, 'CARACTERISTICA_SENSORIAL_COR')]
# Manual Anotation: {'entities': [(12, 22, 'CARACTERISTICA_SENSORIAL_AROMA'), (24, 31, 'CARACTERISTICA_SENSORIAL_AROMA'), (34, 45, 'CARACTERISTICA_SENSORIAL_AROMA')]}
# Model prediction:  entities:  [(12, 22, 'CARACTERISTICA_SENSORIAL_COR')]
# Model prediction:  entities:  [(24, 31, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(34, 45, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Manual Anotation: {'entities': [(10, 23, 'CARACTERISTICA_SENSORIAL_AROMA'), (25, 41, 'CARACTERISTICA_SENSORIAL_AROMA'), (43, 50, 'CARACTERISTICA_SENSORIAL_AROMA'), (53, 64, 'CARACTERISTICA_SENSORIAL_AROMA'), (81, 87, 'CARACTERISTICA_SENSORIAL_AROMA')]}
# Model prediction:  entities:  [(10, 23, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(25, 41, 'CARACTERISTICA_SENSORIAL_AROMA')]
# Model prediction:  entities:  [(53, 64, 'CARACTERISTICA_SENSORIAL_SABOR')]
# Model prediction:  entities:  [(81, 87, 'CARACTERISTICA_SENSORIAL_AROMA')]

# %% [markdown]
# ### Métricas Precision, Recall e f-measure:

# %%
# Apresenta o resultados das métricas para o modelo como um todo, e as métricas do modelo para cada categoria de entidade

print(nlp.evaluate(examples))
# Out:
# {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'pos_acc': None, 'morph_acc': None, 'morph_per_feat': None, 'sents_p': None, 'sents_r': None, 'sents_f': None, 'dep_uas': None, 'dep_las': None, 'dep_las_per_type': None, 'tag_acc': None, 'lemma_acc': None, 'ents_p': 0.8558951965065502, 'ents_r': 0.8032786885245902, 'ents_f': 0.828752642706131, 'ents_per_type': {'NOME_BEBIDA': {'p': 0.8333333333333334, 'r': 0.8333333333333334, 'f': 0.8333333333333334}, 'TIPO_MADEIRA': {'p': 1.0, 'r': 0.9545454545454546, 'f': 0.9767441860465117}, 'RECIPIENTE_ARMAZENAMENTO': {'p': 0.9090909090909091, 'r': 0.9090909090909091, 'f': 0.9090909090909091}, 'CARACTERISTICA_SENSORIAL_SABOR': {'p': 0.3076923076923077, 'r': 0.2222222222222222, 'f': 0.2580645161290323}, 'CARACTERISTICA_SENSORIAL_AROMA': {'p': 0.42105263157894735, 'r': 0.42105263157894735, 'f': 0.42105263157894735}, 'NOME_LOCAL': {'p': 1.0, 'r': 0.8695652173913043, 'f': 0.9302325581395349}, 'TEMPO_ARMAZENAMENTO': {'p': 1.0, 'r': 0.9285714285714286, 'f': 0.962962962962963}, 'GRADUACAO_ALCOOLICA': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'VOLUME': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'PRECO': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'NOME_ORGANIZACAO': {'p': 0.6, 'r': 0.6, 'f': 0.6}, 'CARACTERISTICA_SENSORIAL_COR': {'p': 0.5714285714285714, 'r': 0.5714285714285714, 'f': 0.5714285714285714}, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA': {'p': 1.0, 'r': 0.25, 'f': 0.4}, 'CLASSIFICACAO_BEBIDA': {'p': 1.0, 'r': 0.8888888888888888, 'f': 0.9411764705882353}, 'TEMPO': {'p': 0.875, 'r': 0.7777777777777778, 'f': 0.823529411764706}, 'EQUIPAMENTO_DESTILACAO': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'NOME_PESSOA': {'p': 0.75, 'r': 1.0, 'f': 0.8571428571428571}}, 'speed': 5628.648824778126}

# %% [markdown]
# ### Avaliação do Modelo pelas Métrica Acuracia

# %%
# dictionary which will be populated with the entities and result information
entity_evaluation = {}

# helper function to udpate the entity_evaluation dictionary
def update_results(entity, metric):
    if entity not in entity_evaluation:
        entity_evaluation[entity] = {"correct": 0, "total": 0}
    
    entity_evaluation[entity][metric] += 1

# same as before, see if entities from test set match what spaCy currently predicts
for data in TEST_DATA:
    sentence = data[0]
    entities = data[1]["entities"]

    for entity in entities:
        doc = nlp(sentence)
        correct_text = sentence[entity[0]:entity[1]]

        for ent in doc.ents:
            if ent.label_ == entity[2] and ent.text == correct_text:
                update_results(ent.label_, "correct")
                break

        update_results(entity[2], "total")
print("Resultado para cada categoria:",'\n', entity_evaluation)
# Out:
# Resultado para cada categoria:
#  {'NOME_BEBIDA': {'correct': 25, 'total': 30}, 'TIPO_MADEIRA': {'correct': 21, 'total': 22}, 'RECIPIENTE_ARMAZENAMENTO': {'correct': 10, 'total': 11}, 'CARACTERISTICA_SENSORIAL_SABOR': {'correct': 4, 'total': 18}, 'NOME_LOCAL': {'correct': 20, 'total': 23}, 'TEMPO_ARMAZENAMENTO': {'correct': 13, 'total': 14}, 'GRADUACAO_ALCOOLICA': {'correct': 8, 'total': 8}, 'VOLUME': {'correct': 37, 'total': 37}, 'PRECO': {'correct': 15, 'total': 15}, 'CARACTERISTICA_SENSORIAL_AROMA': {'correct': 8, 'total': 19}, 'CARACTERISTICA_SENSORIAL_COR': {'correct': 4, 'total': 7}, 'CARACTERISTICA_SENSORIAL_CONSISTÊNCIA': {'correct': 1, 'total': 4}, 'CLASSIFICACAO_BEBIDA': {'correct': 16, 'total': 18}, 'NOME_ORGANIZACAO': {'correct': 3, 'total': 5}, 'TEMPO': {'correct': 7, 'total': 9}, 'EQUIPAMENTO_DESTILACAO': {'correct': 1, 'total': 1}, 'NOME_PESSOA': {'correct': 3, 'total': 3}}

# %%
sum_total = 0
sum_correct = 0

for entity in entity_evaluation:
    total = entity_evaluation[entity]["total"]
    correct = entity_evaluation[entity]["correct"]

    sum_total += total
    sum_correct += correct
    
    print("{} | {:.2f}%".format(entity, correct / total * 100))

print()
print("Overall accuracy: {:.2f}%".format(sum_correct / sum_total * 100))
# Out:
# NOME_BEBIDA | 83.33%
# TIPO_MADEIRA | 95.45%
# RECIPIENTE_ARMAZENAMENTO | 90.91%
# CARACTERISTICA_SENSORIAL_SABOR | 22.22%
# NOME_LOCAL | 86.96%
# TEMPO_ARMAZENAMENTO | 92.86%
# GRADUACAO_ALCOOLICA | 100.00%
# VOLUME | 100.00%
# PRECO | 100.00%
# CARACTERISTICA_SENSORIAL_AROMA | 42.11%
# CARACTERISTICA_SENSORIAL_COR | 57.14%
# CARACTERISTICA_SENSORIAL_CONSISTÊNCIA | 25.00%
# CLASSIFICACAO_BEBIDA | 88.89%
# NOME_ORGANIZACAO | 60.00%
# TEMPO | 77.78%
# EQUIPAMENTO_DESTILACAO | 100.00%
# NOME_PESSOA | 100.00%
#
# Overall accuracy: 80.33%

# %% [markdown]
# ## Salvando o Modelo

# %%
# Save the  model to directory

from pathlib import Path
output_dir=Path('C:\\Users\\prisc\\Downloads\\Modelo_spaCy\\model_saved')
nlp.to_disk(output_dir)
print("Saved model to", output_dir)

# %% [markdown]
# ## Importando o Modelo

# %%
# Load the saved model and predict

print("Loading from", output_dir)
nlp_updated = spacy.load(output_dir)
doc = nlp_updated("Eu gostei da Cachaça Artesanal criada em Minas Gerais" )
print("Entidades", [(ent.text, ent.label_) for ent in doc.ents])
